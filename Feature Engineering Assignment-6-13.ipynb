# %% [markdown]
# # Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %%
import pandas as pd
df1=pd.DataFrame({
                'time spend':(10,20,30,35,40,45),
                'exam score':(45,50,55,60,65,70)
})

# %%
df1
# Out:
#    time spend  exam score
# 0          10          45
# 1          20          50
# 2          30          55
# 3          35          60
# 4          40          65
# 5          45          70

# %%
df1.corr()
# Out:
#             time spend  exam score
# time spend    1.000000    0.983904
# exam score    0.983904    1.000000

# %%
# Correlation coefficients are used to measure how strong a relationship is between two variables.
It shows a positive correlation.
Here as spend time for study is increasing,marks is increasing

# %% [markdown]
# # Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

# %%
df2=pd.DataFrame({
                'Sleep time':(6,7,5,6,6,6,7,7,7,5,6,7,8,8),
                'Job Satisfaction':(7,8,6,7,7,7,8,8,8,7,8,9,7,8)
})

# %%
df2
# Out:
#     Sleep time  Job Satisfaction
# 0            6                 7
# 1            7                 8
# 2            5                 6
# 3            6                 7
# 4            6                 7
# 5            6                 7
# 6            7                 8
# 7            7                 8
# 8            7                 8
# 9            5                 7
# 10           6                 8
# 11           7                 9
# 12           8                 7
# 13           8                 8

# %%
df2.corr(method='spearman')
# Out:
#                   Sleep time  Job Satisfaction
# Sleep time          1.000000          0.630714
# Job Satisfaction    0.630714          1.000000

# %%
df2.corr()
# Out:
#                   Sleep time  Job Satisfaction
# Sleep time           1.00000           0.59222
# Job Satisfaction     0.59222           1.00000

# %% [markdown]
# # Q3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

# %%
df3=pd.read_csv('BMI.csv')

# %%
df3.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
df3.shape
# Out:
# (500, 4)

# %%
df3.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
df3.describe()
# Out:
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
df3.corr()
# Out:
# /tmp/ipykernel_172/3136175663.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df3.corr()
#           Height    Weight     Index
# Height  1.000000  0.000446 -0.422223
# Weight  0.000446  1.000000  0.804569
# Index  -0.422223  0.804569  1.000000

# %%
Using Pearson correletion technique,height and weight are positively correlated.
Height and BMI index has negative correlation.
Weight and Index has positive correlation.

# %%
df3.corr(method='spearman')
# Out:
# /tmp/ipykernel_172/3649351717.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df3.corr(method='spearman')
#           Height    Weight     Index
# Height  1.000000 -0.001286 -0.446567
# Weight -0.001286  1.000000  0.808221
# Index  -0.446567  0.808221  1.000000

# %%
Using spearman correletion technique,height and weight are negatively correlated.
Height and BMI index has negative correlation.
Weight and Index has positive correlation.

# %%
df3.sample(10)
# Out:
#      Gender  Height  Weight  Index
# 132  Female     158     153      5
# 260    Male     159     104      5
# 80     Male     164      75      3
# 142    Male     180     149      5
# 270    Male     145     130      5
# 167  Female     156     106      5
# 325  Female     148      54      2
# 402    Male     182      70      2
# 297  Female     140      76      4
# 279    Male     188      57      1

# %% [markdown]
# # Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.

# %%
df4=pd.read_csv('Physical activity.csv')

# %%
df4
# Out:
#     television per day(hrs)  Physiacl Activity per day(hrs)
# 0                         2                               2
# 1                         3                               1
# 2                         2                               2
# 3                         3                               1
# 4                         4                               2
# 5                         2                               1
# 6                         3                               2
# 7                         4                               1
# 8                         5                               2
# 9                         1                               1
# 10                        2                               2
# 11                        3                               1
# 12                        3                               2
# 13                        2                               1
# 14                        1                               2
# ...

# %%
df4.corr()
# Out:
#                                 television per day(hrs)  \
# television per day(hrs)                        1.000000
# Physiacl Activity per day(hrs)                 0.185567
#
#                                 Physiacl Activity per day(hrs)
# television per day(hrs)                               0.185567
# Physiacl Activity per day(hrs)                        1.000000

# %%
Results shows that both has positive association.

# %% [markdown]
# # Q5. A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:

# %%
df5=pd.DataFrame({
                'Age(Years)':(25,42,37,19,31,28),
                'Soft drink Preference':('Coke','Pepsi','Mountain dew','Coke','Pepsi','Coke')
})

# %%
df5
# Out:
#    Age(Years) Soft drink Preference
# 0          25                  Coke
# 1          42                 Pepsi
# 2          37          Mountain dew
# 3          19                  Coke
# 4          31                 Pepsi
# 5          28                  Coke

# %%
df5.corr()
# Out:
# /tmp/ipykernel_172/2952672672.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df5.corr()
#             Age(Years)
# Age(Years)         1.0

# %%
df5.cov()
# Out:
# /tmp/ipykernel_172/2807582726.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df5.cov()
#             Age(Years)
# Age(Years)   68.666667

# %% [markdown]
# # Q6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %%
df6=pd.read_csv('Company data.csv')

# %%
df6
# Out:
#    Sales Representative  Calls per day  Sales per week
# 0                     A             10              12
# 1                     B              7              15
# 2                     C              8              14
# 3                     D              9              16
# 4                     E              4              17
# 5                     F              5              14
# 6                     G              6              15
# 7                     H              7              12
# 8                     I              8              11
# 9                     J              9              17
# 10                    K             10               8
# 11                    L              7              12
# 12                    M              8              15
# 13                    N              9              14
# 14                    O              4              16
# 15                    P              5              17
# ...

# %%
df6.corr()
# Out:
# /tmp/ipykernel_172/2505764688.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df6.corr()
#                 Calls per day  Sales per week
# Calls per day        1.000000       -0.353402
# Sales per week      -0.353402        1.000000

# %%
It shows negative association b/w calls per day and sales per week.
